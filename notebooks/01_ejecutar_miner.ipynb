# %% [markdown]
# # Ejecutar el Miner

# %% [markdown]
# Primero importamos `miner.py` moviendo el systema para que encuentre el modulo miner.py

# %%
import sys
sys.path.append("../miner")
import miner

# %% [markdown]
# Realizamos la extraccion de datos y generacion de SBOMs, vulnerabilidades, workflows y metadatos del repositorio

# %%
miner.main()
# Out:
# Obteniendo repositorios más populares de tj-actions...
# Repositorios seleccionados:
#   - changed-files (2693 estrellas, TypeScript)
#   - branch-names (230 estrellas, None)
#   - verify-changed-files (212 estrellas, Shell)
#   - eslint-changed-files (96 estrellas, Shell)
#   - coverage-badge-go (82 estrellas, Go)
#
# Analizando: changed-files
#    Generando SBOM...
#    Buscando vulnerabilidades...
#    Analizando workflows CI/CD...
#    Analizando 10 workflow(s)...
#    Workflows: 0 problema(s) encontrado(s).
#
# Analizando: branch-names
#    Generando SBOM...
#    Buscando vulnerabilidades...
#    Analizando workflows CI/CD...
#    Analizando 4 workflow(s)...
#    Workflows: 1 problema(s) encontrado(s).
#
# Analizando: verify-changed-files
#    Generando SBOM...
#    Buscando vulnerabilidades...
#    Analizando workflows CI/CD...
#    Analizando 4 workflow(s)...
#    Workflows: 0 problema(s) encontrado(s).
#
# Analizando: eslint-changed-files
#    Generando SBOM...
# ...
